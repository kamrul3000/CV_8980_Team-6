# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt 

img = cv2.imread('C:/Future GSU/2018/Computer Vision/Project/Segmentation Technique/brain.png')
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
img.shape
# Out:
# (252, 231, 3)

# %% [markdown]
# # K-means clustering

# %%
# K-Means Clustering

img = cv2.imread('C:/Future GSU/2018/Computer Vision/Project/Segmentation Technique/brain.png')
Z = img.reshape((-1,3))           #-1,3
print(Z.shape)

# convert to np.float32
Z = np.float32(Z)

# define criteria, number of clusters(K) and apply kmeans()
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 50, 45.0)
K = 7                                                                          #34
ret,label,center=cv2.kmeans(Z,K,None,criteria,5,cv2.KMEANS_RANDOM_CENTERS)

# Now convert back into uint8, and make original image
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))

plt.imshow(cv2.cvtColor(res2, cv2.COLOR_BGR2RGB))
plt.axis("off")
cv2.imwrite("k-clustering.jpg",cv2.cvtColor(res2, cv2.COLOR_BGR2RGB))
# Out:
# (58212, 3)
# True

# %% [markdown]
# ## Erosion

# %%
#Erosion

eroded = cv2.erode(res2, None, iterations=6) 
plt.imshow(eroded, cmap='gray')
plt.axis("off")
cv2.imwrite("erosion.jpg",cv2.cvtColor(eroded, cv2.COLOR_BGR2RGB))
# Out:
# True
